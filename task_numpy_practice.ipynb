# %% [markdown]
# # ДЗ №1 СУНЦ МГУ - Numpy practice

# %% [markdown]
# **Среда:** Python 3.14.7. Локальные модули `functions.py` и `functions_vectorizedtorizedtorized.py` повторно импортируются при каждом запуске ячейки с решением.

# %% [markdown]
# ### Туториальные задачи
# __(9 баллов)__
#
# Ниже приведены задачи на работу с numpy-массивами. Для каждой из задач нужно привести 2 реализации: одна без использования numpy (cчитайте, что там, где на входе или выходе должны быть numpy array, будут просто списки), а вторая полностью векторизованная (без использования питоновских циклов/map/list comprehension). Невекторизованная реализация каждой из задач оценивается в __0.5 балла__, векторизованная – в __1 балл__.
#
# Реализации без использования векторизации нужно записать в файл functions.py, а векторизованные &mdash; в файл functions_vectorized.py
#
# Для каждой задачи, приведённой ниже сравните скорость работы невекторизованной и векторизованной реализации. С помощью пакета matplotlib постройте графики времени работы в зависимости от размера данных. __Графики должны выглядеть опрятно!__ То есть должны быть подписаны оси, названия графиков, и т.д. Например, ниже представлены хороший и плохой графики:

# %%
from importlib import reload

import matplotlib.pyplot as plt
import numpy as np

import functions
import functions_vectorized

# %matplotlib inline


def reload_solution_modules():
    """Reload the two local solution modules after their files change."""
    reload(functions)
    reload(functions_vectorized)


data_size = np.array([10, 30, 70, 120])
time_non_vectorized = data_size**2 + 10
time_vectorized = data_size**1.5

figure, (axis_bad, axis_good) = plt.subplots(1, 2, figsize=(13, 5))

axis_bad.plot(data_size, time_non_vectorized)
axis_bad.plot(data_size, time_vectorized)
axis_bad.set_title("Плохой график")
axis_bad.set_xlabel("Размер данных")
axis_bad.set_ylabel("Время")

axis_good.plot(data_size, time_non_vectorized, label="Невекторизованная")
axis_good.plot(data_size, time_vectorized, label="Векторизованная")
axis_good.set_title("Хороший график")
axis_good.set_xlabel("Длина массива")
axis_good.set_ylabel("Время (с)")
axis_good.grid(True, alpha=0.3)
axis_good.legend()

figure.tight_layout()
plt.show()

# %% [markdown]
# * __Задача 1__: Подсчитать произведение ненулевых элементов на диагонали прямоугольной матрицы.
#  Например, для X = np.array([[1, 0, 1], [2, 0, 2], [3, 0, 3], [4, 4, 4]]) ответ – 3.

# %%
import functions
import functions_vectorized

from importlib import reload

def reload_solution_modules():
    """Reload the two local solution modules after their files change."""
    reload(functions)
    reload(functions_vectorized)

reload_solution_modules() 

import timeit
import matplotlib.pyplot as plt
import numpy as np

sizes = [1000, 10000, 20000, 50000]
times_pure, times_vec = [], []

for n in sizes:
    x = np.random.randint(0, 2, size=(n, n + np.random.randint(-5, 6)))
    t_pure = timeit.timeit(lambda: functions.prod_non_zero_diag(x), number=10) / 10
    t_vec   = timeit.timeit(lambda: functions_vectorized.prod_non_zero_diag(x), number=100) / 100
    times_pure.append(t_pure)
    times_vec.append(t_vec)

plt.figure(figsize=(8, 5))
plt.plot(sizes, times_pure, marker='o', label='Без numpy')
plt.plot(sizes, times_vec,   marker='o', label='С numpy')
plt.xlabel('Длина массива')
plt.xticks(sizes)
plt.ticklabel_format(axis='x', style='plain', useOffset=False)
plt.ylabel('Время (с)')
plt.title('Сравнение скорости: prod_non_zero_diag')
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
#
#
# * __Задача 2__: Даны два вектора x и y. Проверить, задают ли они одно и то же мультимножество.
#   Например, для x = np.array([1, 2, 2, 4]), y = np.array([4, 2, 1, 2]) ответ – True.

# %%
import functions
import functions_vectorized

from importlib import reload

def reload_solution_modules():
    """Reload the two local solution modules after their files change."""
    reload(functions)
    reload(functions_vectorized)

reload_solution_modules() 

import timeit
import matplotlib.pyplot as plt
import numpy as np

sizes = [10000, 100000, 200000, 500000, 1000000]
times_pure, times_vec = [], []

for n in sizes:
    x = np.random.randint(0, 2, size=n)
    y = np.random.randint(0, 2, size=n)
    t_pure = timeit.timeit(lambda: functions.are_multisets_equal(x,y), number=10) / 10
    t_vec   = timeit.timeit(lambda: functions_vectorized.are_multisets_equal(x,y), number=100) / 100
    times_pure.append(t_pure)
    times_vec.append(t_vec)

plt.figure(figsize=(8, 5))
plt.plot(sizes, times_pure, marker='o', label='Без numpy')
plt.plot(sizes, times_vec,   marker='o', label='С numpy')
plt.xlabel('Длина каждого массива')
plt.xticks(sizes)
plt.ticklabel_format(axis='x', style='plain', useOffset=False)
plt.ylabel('Время (с)')
plt.title('Сравнение скорости: are_multisets_equal')
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# * __Задача 3__: Найти максимальный элемент в векторе x среди элементов, перед которыми стоит нулевой.
#  Например, для x = np.array([6, 2, 0, 3, 0, 0, 5, 7, 0]) ответ – 5.

# %%
import functions
import functions_vectorized

from importlib import reload

def reload_solution_modules():
    """Reload the two local solution modules after their files change."""
    reload(functions)
    reload(functions_vectorized)

reload_solution_modules() 

import timeit
import matplotlib.pyplot as plt
import numpy as np

sizes = [10000, 100000, 200000, 500000, 1000000]
times_pure, times_vec = [], []

for n in sizes:
    x = np.random.randint(0, 10, size=n)
    t_pure = timeit.timeit(lambda: functions.max_after_zero(x), number=10) / 10
    t_vec   = timeit.timeit(lambda: functions_vectorized.max_after_zero(x), number=100) / 100
    times_pure.append(t_pure)
    times_vec.append(t_vec)

plt.figure(figsize=(8, 5))
plt.plot(sizes, times_pure, marker='o', label='Без numpy')
plt.plot(sizes, times_vec,   marker='o', label='С numpy')
plt.xlabel('Длина массива')
plt.xticks(sizes)
plt.ticklabel_format(axis='x', style='plain', useOffset=False)
plt.ylabel('Время (с)')
plt.title('Сравнение скорости: max_after_zero')
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
#
#
# * __Задача 4__: Дан трёхмерный массив, содержащий изображение, размера (height, width, numChannels), а также вектор длины numChannels. Сложить каналы изображения с указанными весами, и вернуть результат в виде матрицы размера (height, width). В ноутбуке приведите пример работы функции – преобразуйте цветное изображение в оттенки серого, использовав коэффициенты np.array([0.299, 0.587, 0.114]). Считать реальное изображение можно с помощью `PIL.Image.open` из пакета Pillow: `img = np.asarray(Image.open(path).convert("RGB"))`. Устаревшая функция `scipy.misc.imread` удалена из современных версий SciPy.

# %%
import functions
import functions_vectorized

from importlib import reload

def reload_solution_modules():
    """Reload the two local solution modules after their files change."""
    reload(functions)
    reload(functions_vectorized)

reload_solution_modules()

from PIL import Image

import timeit
import numpy as np
import matplotlib.pyplot as plt

img = np.asarray(Image.open("flower.jpg").convert("RGB"))

coefs = np.array([0.299, 0.587, 0.114])

gray_vec = functions_vectorized.convert_image(img, coefs)
gray_pure = np.asarray(functions.convert_image(img, coefs))

plt.figure(figsize=(6, 5))
plt.imshow(img)
plt.title("Исходное изображение")
plt.axis("off")
plt.show()

plt.figure(figsize=(6, 5))
plt.imshow(gray_pure, cmap="gray")
plt.title("Оттенки серого без numpy")
plt.axis("off")
plt.show()

plt.figure(figsize=(6, 5))
plt.imshow(gray_vec, cmap="gray")
plt.title("Оттенки серого с numpy")
plt.axis("off")
plt.show()



def bench(fn, *args, number=10):
    return timeit.timeit(lambda: fn(*args), number=number) / number

sizes = [320, 640, 1280, 2560]
coefs = np.array([0.299, 0.587, 0.114])
t_plain, t_vec = [], []

for s in sizes:
    img = np.random.randint(0, 256, size=(s, s, 3))
    t_plain.append(bench(functions.convert_image, img, coefs, number=3))
    t_vec.append(bench(functions_vectorized.convert_image, img, coefs, number=10))

plt.figure(figsize=(8, 5))
plt.plot(sizes, t_plain, marker='o', label='Без numpy')
plt.plot(sizes, t_vec,   marker='s', label='С numpy')
plt.xlabel('Сторона изображения (пиксели)')
plt.ylabel('Время (с)')
plt.title('Сравнение скорости: convert_image')
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# * __Задача 5__: Реализовать кодирование длин серий (Run-length encoding). Для некоторого вектора x необходимо вернуть кортеж из двух векторов одинаковой длины. Первый содержит числа, а второй - сколько раз их нужно повторить.
#  Например, для x = np.array([2, 2, 2, 3, 3, 3, 5]) ответ – (np.array([2, 3, 5]), np.array([3, 3, 1])).

# %%
import functions
import functions_vectorized

from importlib import reload

def reload_solution_modules():
    """Reload the two local solution modules after their files change."""
    reload(functions)
    reload(functions_vectorized)

reload_solution_modules() 

import timeit
import matplotlib.pyplot as plt
import numpy as np

sizes = [10000, 100000, 200000, 500000, 1000000]
times_pure, times_vec = [], []

for n in sizes:
    x = np.random.randint(0, 10, size=n)
    t_pure = timeit.timeit(lambda: functions.run_length_encoding(x), number=10) / 10
    t_vec   = timeit.timeit(lambda: functions_vectorized.run_length_encoding(x), number=100) / 100
    times_pure.append(t_pure)
    times_vec.append(t_vec)

plt.figure(figsize=(8, 5))
plt.plot(sizes, times_pure, marker='o', label='Без numpy')
plt.plot(sizes, times_vec,   marker='o', label='С numpy')
plt.xlabel('Длина массива')
plt.xticks(sizes)
plt.ticklabel_format(axis='x', style='plain', useOffset=False)
plt.ylabel('Время (с)')
plt.title('Сравнение скорости: run_length_encoding')
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
#
#
# * __Задача 6__: Даны две выборки объектов - X и Y. Вычислить матрицу евклидовых расстояний между объектами. Дополнительно сравните с функцией scipy.spatial.distance.cdist по скорости работы (сравнения приведите ниже в ноутбуке).

# %%
import functions
import functions_vectorized

from importlib import reload
from scipy.spatial.distance import cdist

def reload_solution_modules():
    """Reload the two local solution modules after their files change."""
    reload(functions)
    reload(functions_vectorized)

reload_solution_modules() 

import timeit
import matplotlib.pyplot as plt
import numpy as np

sizes = [100, 300, 500, 800, 1000]
d = 3 # размерность

times_pure, times_vec, times_cdist = [], [], []

for n in sizes:
    X = np.random.randint(0, 10, size=(n, d))
    Y = np.random.randint(0, 10, size=(n, d))

    t_pure = timeit.timeit(lambda: functions.pairwise_distance(X, Y), number=3) / 3
    t_vec = timeit.timeit(lambda: functions_vectorized.pairwise_distance(X, Y), number=100) / 100
    t_cdist = timeit.timeit(lambda: cdist(X, Y, metric='euclidean'), number=100) / 100

    times_pure.append(t_pure)
    times_vec.append(t_vec)
    times_cdist.append(t_cdist)

plt.figure(figsize=(8, 5))
plt.plot(sizes, times_pure, marker='o', label='Без numpy (циклы)')
plt.plot(sizes, times_vec,   marker='s', label='Векторизованная (numpy)')
plt.plot(sizes, times_cdist, marker='^', label='scipy.cdist')
plt.xlabel('Количество объектов (n)')
plt.xticks(sizes)
plt.ticklabel_format(axis='x', style='plain', useOffset=False)
plt.ylabel('Время (с)')
plt.title('Сравнение скорости: pairwise_distance')
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Туториал по Markdown
#
# __(1 балл)__
#
# Напишите краткий (а в данной домашке ещё и почти бесмысленный) отчёт с использованием 4-5 различных вариантов разметки/выделения текста.

# %% [markdown]
# Выше решены задачи на работу <i>NumPy</i>-массивами. Для каждой из задач приведено <u>2 реализации</u>: <u>одна</u> без использования <i>NumPy</i>, а <u>вторая</u> полностью векторизованная. <b>Графики</b> <s>вроде красивые!</s> __опрятные__!
